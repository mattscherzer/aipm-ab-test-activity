# %% [markdown]
# # Step 2 — Synthetic Data for the Homepage Dek A/B Test
#
# This notebook **generates and explores** the dataset used in the Meridian homepage-dek experiment.
# It is the notebook form of `make_synthetic_data.py` — same logic, same seed, same output file, so
# running either produces a byte-identical `ab_test_sessions.csv`.
#
# ### The design it has to honour (from Step 1)
#
# | | |
# |---|---|
# | **Treatment** | A one-to-two-sentence factual summary (*dek*) rendered beneath headlines in homepage slots 1–5 |
# | **Primary KPI** | Session-denominated CTR — share of homepage sessions with ≥1 article click |
# | **Baseline** | 34.1% |
# | **Unit of randomisation** | User (sticky) |
# | **Unit of analysis** | User — cannot be finer than randomisation |
# | **Window** | 2026-09-22 → 2026-10-26 (35 days = 5 whole weeks) |
# | **Ship threshold** | +5% relative |
# | **Power target** | +2% relative |
#
# ### Two design choices worth understanding before reading the code
#
# **Rows are sessions, not users.** Pre-aggregating to one row per user would hide the problem the
# plan cares about. With session rows and a repeating `user_id`, the clustering is *in the data*: a
# naive session-level test reports a standard error about 11% too small, and you can see that rather
# than take it on faith.
#
# **`deks_available` and `deks_rendered` are separate columns.** `deks_available` records whether a
# reporter wrote a dek — it is logged in **both** arms and is independent of assignment, so it is
# safe to filter on. `deks_rendered` is *caused by* treatment (always 0 in arm A), so filtering on it
# would strip sessions from one arm only and destroy the randomisation. The two columns exist so the
# notebook can demonstrate the difference instead of describing it.

# %% [markdown]
# ## 1. Configuration
#
# Every knob lives here. Change one, re-run the notebook, get a different world.

# %%
import csv, math, random
from datetime import date, timedelta

SEED = 20260922
random.seed(SEED)

# --- scale and window ------------------------------------------------------
N_USERS    = 100_000
START      = date(2026, 9, 22)          # launch
END        = date(2026, 10, 26)         # day 35 -> exactly 5 whole weeks
N_DAYS     = (END - START).days + 1

# --- allocation ------------------------------------------------------------
P_ASSIGN_B = 0.48                       # intended A 52 / B 48 (cautious ramp, deliberately uneven)

# --- target rates ----------------------------------------------------------
TARGET_A   = 0.341                      # documented baseline session CTR
TARGET_B   = 0.382                      # +12.0% relative (bottom of the 10-30% band in the brief)

# --- heterogeneity and structure ------------------------------------------
SIGMA_USER     = 1.10                   # user random effect, logit scale -> ICC ~0.27
NEWS_SPIKE_DAY = 18                     # Oct 10: big story

# covariate effects on logit(click)
B_MOBILE, B_DESKTOP, B_TABLET = -0.16, 0.30, 0.05
B_RETURNING, B_NEW            =  0.22, -0.30
B_LOGGED_IN, B_SUBSCRIBER     =  0.28,  0.35

NOVELTY_PEAK, NOVELTY_TAU = 0.25, 9.0   # treatment x (1 + 0.25*exp(-day/9))
DEK_COVERAGE_MEAN         = 0.88        # share of in-scope stories with a dek written
DEK_COVERAGE_SPIKE_DAY    = 0.71        # breaking news outruns dek writing
IMPRESSION_PENALTY_B      = 0.955       # vertical space: ~4.5% fewer headlines seen in arm B

print(f"{N_DAYS} days ({N_DAYS // 7} whole weeks): {START} -> {END}")
print(f"{N_USERS:,} users, intended allocation A {(1-P_ASSIGN_B):.0%} / B {P_ASSIGN_B:.0%}")
print(f"targets: A {TARGET_A:.1%}  B {TARGET_B:.1%}  (rel {TARGET_B/TARGET_A-1:+.1%})")
# Out:
# 35 days (5 whole weeks): 2026-09-22 -> 2026-10-26
# 100,000 users, intended allocation A 52% / B 48%
# targets: A 34.1%  B 38.2%  (rel +12.0%)

# %% [markdown]
# ## 2. Samplers
#
# Stdlib only — no numpy needed for generation. `random.gammavariate` and `random.gauss` do the heavy lifting.

# %%
def poisson(lam):
    """Knuth's method. Fine for the small lambdas used here."""
    if lam <= 0:
        return 0
    L, k, p = math.exp(-lam), 0, 1.0
    while True:
        p *= random.random()
        if p <= L:
            return k
        k += 1

def binomial(n, p):
    return sum(1 for _ in range(n) if random.random() < p)

def sigmoid(x):
    if x >= 0:
        return 1.0 / (1.0 + math.exp(-x))
    e = math.exp(x)
    return e / (1.0 + e)

def clamp(x, lo, hi):
    return lo if x < lo else hi if x > hi else x

# %% [markdown]
# ## 3. Day-level structure
#
# Three things vary by calendar day, and all three matter to the analysis:
#
# - **Traffic** — weekends run at 78–82% of a weekday, plus lognormal day-to-day news noise
# - **CTR shift** — weekend reading is slightly stickier per session
# - **Dek coverage** — normally ~88%, but it *collapses on the big news day*
#
# That last correlation is deliberate. Coverage and news intensity move together, which is precisely
# why the availability-conditioned analysis is a **subgroup** rather than a clean causal estimate:
# filtering to full-coverage sessions quietly filters out breaking-news sessions, and those behave
# differently for reasons that have nothing to do with deks.

# %%
def build_days():
    days = []
    for i in range(N_DAYS):
        d = START + timedelta(days=i)
        dow = d.weekday()                              # 0 = Monday
        traffic = 1.0
        if   dow == 5: traffic = 0.78                  # Sat
        elif dow == 6: traffic = 0.82                  # Sun
        traffic *= math.exp(random.gauss(0, 0.12))     # day-to-day news noise
        ctr_shift = 0.05 if dow >= 5 else 0.0
        coverage  = DEK_COVERAGE_MEAN + random.gauss(0, 0.035)
        if i == NEWS_SPIKE_DAY:
            traffic   *= 1.90
            ctr_shift += 0.18
            coverage   = DEK_COVERAGE_SPIKE_DAY
        days.append({"day_index": i, "date": d.isoformat(),
                     "dow": ["Mon","Tue","Wed","Thu","Fri","Sat","Sun"][dow],
                     "traffic": traffic, "ctr_shift": ctr_shift,
                     "coverage": clamp(coverage, 0.55, 0.99)})
    total = sum(x["traffic"] for x in days)
    cum, acc = [], 0.0
    for x in days:
        acc += x["traffic"] / total
        cum.append(acc)
    return days, cum

DAYS, DAY_CUM = build_days()

def pick_day():
    """Binary search on the cumulative traffic weights."""
    r = random.random()
    lo, hi = 0, N_DAYS - 1
    while lo < hi:
        mid = (lo + hi) // 2
        if r <= DAY_CUM[mid]: hi = mid
        else:                 lo = mid + 1
    return lo

print(f"built {len(DAYS)} days")
# Out:
# built 35 days

# %% [markdown]
# Have a look at the day table — sort it by any column to see the weekly rhythm and the shock day.

# %%
import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.width", 140)

days_df = pd.DataFrame(DAYS)
days_df["is_shock"] = days_df["day_index"] == NEWS_SPIKE_DAY
display(days_df.sort_values("traffic", ascending=False).head(8))
print("mean coverage:", round(days_df.coverage.mean(), 4))
print("weekend vs weekday traffic:",
      round(days_df[days_df.dow.isin(["Sat","Sun"])].traffic.mean() /
            days_df[~days_df.dow.isin(["Sat","Sun"])].traffic.mean(), 3))
# Out:
#     day_index        date  dow   traffic  ctr_shift  coverage  is_shock
# 18         18  2026-10-10  Sat  1.315213       0.23  0.710000      True
# 0           0  2026-09-22  Tue  1.159226       0.00  0.850367     False
# 9           9  2026-10-01  Thu  1.148966       0.00  0.912665     False
# 6           6  2026-09-28  Mon  1.116240       0.00  0.837310     False
# 8           8  2026-09-30  Wed  1.099107       0.00  0.847641     False
# 14         14  2026-10-06  Tue  1.079061       0.00  0.900566     False
# 17         17  2026-10-09  Fri  1.071949       0.00  0.882254     False
# 22         22  2026-10-14  Wed  1.068073       0.00  0.932661     False
# mean coverage: 0.8758
# weekend vs weekday traffic: 0.899

# %% [markdown]
# ## 4. Users
#
# Each user gets a **latent click propensity** drawn from `Normal(0, 1.10)` on the logit scale. This is
# the single most important line in the generator: it is what makes a user's sessions correlated with
# each other, which is what makes the unit-of-analysis decision from Step 1 actually matter.
#
# At `SIGMA_USER = 1.10` the intra-class correlation is roughly
#
# $$\text{ICC} = \frac{\sigma_u^2}{\sigma_u^2 + \pi^2/3} = \frac{1.21}{1.21 + 3.29} \approx 0.27$$
#
# which at ~1.5 sessions per user implies a design effect near 1.23. Step 1 assumed 1.24.
#
# Session counts are **gamma-Poisson** (negative-binomial), not Poisson — real users are overdispersed:
# most visit once, a few visit constantly.

# %%
def build_users(n):
    users = []
    for i in range(n):
        logged_in  = random.random() < 0.31
        subscriber = logged_in and random.random() < 0.194     # ~6% of users overall
        r = random.random()
        device = "mobile" if r < 0.68 else ("desktop" if r < 0.97 else "tablet")
        p_new  = 0.08 if logged_in else 0.47
        visitor = "new" if random.random() < p_new else "returning"
        lam = random.gammavariate(0.60, 0.85)                  # overdispersion
        users.append({"id": i,
                      "variant": "B" if random.random() < P_ASSIGN_B else "A",
                      "u": random.gauss(0, SIGMA_USER),
                      "logged_in": logged_in, "subscriber": subscriber,
                      "device": device, "visitor": visitor,
                      "n_sessions": 1 + poisson(lam)})
    return users

# %% [markdown]
# ## 5. Session generation
#
# The click model is a logistic regression whose coefficients we wrote ourselves:
#
# ```
# logit(click) = intercept
#              + user_effect                        # latent propensity
#              + device + visitor_type + login + subscriber
#              + day_ctr_shift
#              + treat_coef x exposure x novelty
# ```
#
# `exposure` is `deks_rendered / inscope_impressions` — **zero for every arm-A session**, and for arm B
# it is the *fraction* of in-scope headlines that actually carried a dek. That fraction is what creates
# genuine ITT dilution: a coverage rate of 88% means arm-B sessions receive, on average, 88% of the
# treatment, so the measured ITT effect is ~88% of the full effect.

# %%
def gen_sessions(users, intercept, treat_coef, emit=None):
    """Return (rate_A, rate_B). If `emit` is given, call it with each row tuple."""
    n_click_a = n_a = n_click_b = n_b = 0
    sid = 0
    for u in users:
        base = (u["u"]
                + (B_MOBILE  if u["device"] == "mobile"  else
                   B_DESKTOP if u["device"] == "desktop" else B_TABLET)
                + (B_RETURNING if u["visitor"] == "returning" else B_NEW)
                + (B_LOGGED_IN  if u["logged_in"]  else 0.0)
                + (B_SUBSCRIBER if u["subscriber"] else 0.0))
        is_b = u["variant"] == "B"

        for _ in range(u["n_sessions"]):
            sid += 1
            di  = pick_day()
            day = DAYS[di]

            # device can vary session to session
            if random.random() < 0.88:
                device = u["device"]
            else:
                device = random.choice([d for d in ("mobile","desktop","tablet")
                                        if d != u["device"]])

            # headlines seen; arm B sees fewer because deks take vertical space
            mu = 10.2 * (IMPRESSION_PENALTY_B if is_b else 1.0)
            hp = int(clamp(round(math.exp(random.gauss(math.log(mu), 0.45))), 1, 48))

            inscope = min(5, hp)
            skip_p  = 0.18 if device == "mobile" else 0.12
            if inscope > 1 and random.random() < skip_p:
                inscope -= 1

            deks_avail = binomial(inscope, day["coverage"])
            deks_rend  = deks_avail if is_b else 0          # <- never non-zero in arm A
            full_cov   = 1 if deks_avail == inscope else 0

            exposure = (deks_rend / inscope) if inscope else 0.0
            novelty  = 1.0 + NOVELTY_PEAK * math.exp(-di / NOVELTY_TAU)

            logit   = intercept + base + day["ctr_shift"] + treat_coef * exposure * novelty
            clicked = 1 if random.random() < sigmoid(logit) else 0

            if is_b: n_b += 1; n_click_b += clicked
            else:    n_a += 1; n_click_a += clicked

            if emit is not None:
                if clicked:
                    articles = 1 + poisson(0.42)
                    lift     = 1 if exposure > 0 else 0     # better-qualified clicks in B
                    scroll   = int(round(clamp(random.gauss(52 + 2.2*lift, 18), 5, 100)))
                    tpage    = int(round(math.exp(random.gauss(math.log(78) + 0.06*lift, 0.62))))
                    bounced  = 1 if random.random() < (0.38 - 0.025*lift) else 0
                    tail = (articles, scroll, tpage, bounced)
                else:
                    tail = (0, "", "", "")                  # blank, not zero
                emit((f"S{sid:07d}", f"U{u['id']:06d}", u["variant"],
                      day["date"], day["dow"], device,
                      int(u["logged_in"]), int(u["subscriber"]), u["visitor"],
                      hp, inscope, deks_avail, deks_rend, full_cov, clicked, *tail))

    return (n_click_a / n_a if n_a else 0), (n_click_b / n_b if n_b else 0)

# %% [markdown]
# ## 6. Calibration
#
# We want arm A to land on 34.1% and arm B on 38.2%. Rather than hand-tuning the intercept and the
# treatment coefficient, solve for them: generate, measure, step the parameter in logit space, repeat.
#
# Calibration runs against **the same user set that gets written out**, otherwise the realised rates
# drift by a few tenths of a point between the calibration sample and the final run.

# %%
def calibrate(cal_users, intercept=-0.95, treat=0.55, rounds=9, verbose=True):
    logit_t = lambda p: math.log(p / (1 - p))
    for k in range(rounds):
        random.seed(SEED + 2)
        ra, _ = gen_sessions(cal_users, intercept, treat)
        intercept += (logit_t(TARGET_A) - logit_t(ra)) * 0.95
        random.seed(SEED + 2)
        _, rb = gen_sessions(cal_users, intercept, treat)
        treat += (logit_t(TARGET_B) - logit_t(rb)) * 0.95
        if verbose and (k % 3 == 2 or k == rounds - 1):
            print(f"  round {k+1:>2}: A={ra:.4f} B={rb:.4f}  "
                  f"intercept={intercept:+.4f} treat={treat:+.4f}")
    return intercept, treat

random.seed(SEED + 10)
users = build_users(N_USERS)
print(f"{len(users):,} users built; {sum(u['n_sessions'] for u in users):,} sessions to generate\n")

INTERCEPT, TREAT_COEF = calibrate(users)
print(f"\nsolved: intercept={INTERCEPT:.4f}  treat_coef={TREAT_COEF:.4f}")
# Out:
# 100,000 users built; 150,568 sessions to generate
#   round  3: A=0.3414 B=0.3873  intercept=-0.9830 treat=+0.2395
#   round  6: A=0.3410 B=0.3821  intercept=-0.9836 treat=+0.2284
#   round  9: A=0.3410 B=0.3820  intercept=-0.9835 treat=+0.2282
#
# solved: intercept=-0.9835  treat_coef=0.2282

# %% [markdown]
# ## 7. Write the CSV — with a guard
#
# Two safety rails, because this cell overwrites the dataset that `03-results.md` reports on:
#
# - **`REGENERATE = False`** skips generation entirely and uses the file already on disk. Set it to
#   `False` once you are analysing rather than generating, so a top-to-bottom re-run cannot clobber
#   your data.
# - **A checksum** against the exact file the results doc describes. If you change a knob in cell 1 —
#   which is a perfectly reasonable thing to do — the checksum will not match, and the cell says so
#   loudly. That is a notice, not an error: it means the numbers in `03-results.md` describe a
#   different dataset than the one you now have.

# %%
import hashlib, os

# ---------------------------------------------------------------- the guard
REGENERATE      = True     # False -> use the CSV already on disk, do not rewrite it
EXPECTED_SHA256 = "b6d68646e776aca738fb3857147e387350f9aad3907844e030b53bd1b0a4fffe"
# --------------------------------------------------------------------------

HEADER = ["session_id","user_id","variant","session_date","day_of_week","device",
          "is_logged_in","is_subscriber","visitor_type","homepage_impressions",
          "inscope_impressions","deks_available","deks_rendered","full_dek_coverage",
          "clicked","articles_clicked","scroll_depth_pct","time_on_page_sec","bounced"]

OUT = "ab_test_sessions.csv"

def sha256(path):
    h = hashlib.sha256()
    with open(path, "rb") as f:
        for chunk in iter(lambda: f.read(1 << 20), b""):
            h.update(chunk)
    return h.hexdigest()

if REGENERATE or not os.path.exists(OUT):
    if not REGENERATE:
        print(f"{OUT} not found -> generating anyway\n")
    with open(OUT, "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(HEADER)
        random.seed(SEED + 11)
        rate_a, rate_b = gen_sessions(users, INTERCEPT, TREAT_COEF, emit=w.writerow)
    print(f"wrote {OUT}")
else:
    import pandas as _pd
    _g = _pd.read_csv(OUT, usecols=["variant","clicked"]).groupby("variant").clicked.mean()
    rate_a, rate_b = _g["A"], _g["B"]
    print(f"REGENERATE = False -> kept the existing {OUT}, nothing overwritten")

print(f"arm A {rate_a:.4%}   arm B {rate_b:.4%}   relative lift {(rate_b/rate_a - 1):+.2%}")

digest = sha256(OUT)
if digest == EXPECTED_SHA256:
    print(f"\nchecksum OK  {digest[:16]}...")
    print("This is the dataset that 03-results.md reports on.")
else:
    print("\n" + "!" * 78)
    print("CHECKSUM MISMATCH — this is not the dataset 03-results.md describes.")
    print(f"  on disk  {digest}")
    print(f"  expected {EXPECTED_SHA256}")
    print("A config value or the seed changed. That is fine and often the point, but every")
    print("number in 03-results.md (+11.90%, z = 14.74, coverage 87.4%, the CXL runs) belongs")
    print("to the old file. Re-run the analysis before quoting any of them.")
    print("!" * 78)
# Out:
# wrote ab_test_sessions.csv
# arm A 34.0141%   arm B 38.0633%   relative lift +11.90%
#
# checksum OK  b6d68646e776aca7...
# This is the dataset that 03-results.md reports on.

# %% [markdown]
# ---
# # Exploring the data
#
# Everything below reads the CSV back and pokes at it. This is the part to sort, slice and re-run.

# %%
df = pd.read_csv(OUT, parse_dates=["session_date"])
print(f"{len(df):,} rows x {df.shape[1]} columns   |   {df.user_id.nunique():,} users   "
      f"|   {df.session_date.dt.date.nunique()} days")
df.head(10)
# Out:
# 150,568 rows x 19 columns   |   100,000 users   |   35 days
#   session_id  user_id variant session_date day_of_week   device  is_logged_in  is_subscriber visitor_type  homepage_impressions  \
# 0   S0000001  U000000       A   2026-09-24         Thu   mobile             1              0    returning                     8
# 1   S0000002  U000000       A   2026-10-23         Fri   mobile             1              0    returning                    16
# 2   S0000003  U000001       A   2026-09-27         Sun   mobile             0              0          new                    15
# 3   S0000004  U000002       A   2026-09-26         Sat   mobile             0              0    returning                    10
# 4   S0000005  U000003       A   2026-09-29         Tue  desktop             0              0          new                    12
# 5   S0000006  U000004       B   2026-10-23         Fri   mobile             0              0          new                     8
# 6   S0000007  U000005       B   2026-10-23         Fri  desktop             0              0          new                     9
# 7   S0000008  U000005       B   2026-09-24         Thu  desktop             0              0          new                    12
# 8   S0000009  U000006       B   2026-10-20         Tue   mobile             1              0    returning                     6
# 9   S0000010  U000007       B   2026-09-30         Wed  desktop             0              0          new                    11
#
#    inscope_impressions  deks_available  deks_rendered  full_dek_coverage  clicked  articles_clicked  scroll_depth_pct  time_on_page_sec  \
# 0                    5               5              0                  1        0                 0               NaN               NaN
# 1                    4               4              0                  1        1                 1              67.0             118.0
# 2                    5               5              0                  1        0                 0               NaN               NaN
# 3                    5               3              0                  0        0                 0               NaN               NaN
# 4                    4               3              0                  0        1                 2              40.0              31.0
# 5                    5               5              5                  1        0                 0               NaN               NaN
# 6                    5               5              5                  1        1                 2              46.0             203.0
# 7                    5               5              5                  1        0                 0               NaN               NaN
# 8                    5               5              5                  1        0                 0               NaN               NaN
# 9                    5               4              4                  0        1                 1              53.0             303.0
#
#    bounced
# 0      NaN
# 1      0.0
# 2      NaN
# 3      NaN
# 4      0.0
# 5      NaN
# 6      0.0
# 7      NaN
# 8      NaN
# 9      1.0

# %% [markdown]
# ### Column dictionary
#
# | Column | Type | Notes |
# |---|---|---|
# | `session_id` | string | `S0000001`, unique |
# | `user_id` | string | `U000000`. Repeats across rows. **Unit of randomisation and analysis.** |
# | `variant` | `A` / `B` | A = headline only, B = headline + dek. Constant within user. |
# | `session_date` | date | Within the 35-day window |
# | `day_of_week` | string | `Mon`…`Sun`, derived — for weekly-cycle checks |
# | `device` | `mobile`/`desktop`/`tablet` | Per session; 88% match the user's primary device |
# | `is_logged_in` | 0/1 | ~31% of sessions |
# | `is_subscriber` | 0/1 | Subset of logged-in, ~6% of users |
# | `visitor_type` | `new`/`returning` | Fixed per user |
# | `homepage_impressions` | int 1–48 | Headlines seen across all slots |
# | `inscope_impressions` | int 1–5 | Of slots 1–5, how many were seen |
# | `deks_available` | int ≤ `inscope_impressions` | **Logged in both arms.** Treatment-independent → safe to filter on. |
# | `deks_rendered` | int | **Always 0 in arm A.** Equals `deks_available` in arm B. Treatment-determined → never filter on this. |
# | `full_dek_coverage` | 0/1 | 1 when `deks_available == inscope_impressions` |
# | `clicked` | 0/1 | **PRIMARY KPI numerator.** Session CTR = mean of this column. |
# | `articles_clicked` | int | 0 when `clicked = 0` |
# | `scroll_depth_pct` | int 5–100 | **Blank when `clicked = 0`** |
# | `time_on_page_sec` | int | **Blank when `clicked = 0`** |
# | `bounced` | 0/1 | **Blank when `clicked = 0`** |
#
# `ad_impressions` is deliberately absent — Step 1 excluded it as not instrumented.

# %%
df.dtypes.to_frame("dtype").assign(
    non_null=df.notna().sum(),
    nulls=df.isna().sum(),
    n_unique=df.nunique(),
)
# Out:
#                                dtype  non_null  nulls  n_unique
# session_id                       str    150568      0    150568
# user_id                          str    150568      0    100000
# variant                          str    150568      0         2
# session_date          datetime64[us]    150568      0        35
# day_of_week                      str    150568      0         7
# device                           str    150568      0         3
# is_logged_in                   int64    150568      0         2
# is_subscriber                  int64    150568      0         2
# visitor_type                     str    150568      0         2
# homepage_impressions           int64    150568      0        48
# inscope_impressions            int64    150568      0         5
# deks_available                 int64    150568      0         6
# deks_rendered                  int64    150568      0         6
# full_dek_coverage              int64    150568      0         2
# clicked                        int64    150568      0         2
# articles_clicked               int64    150568      0         8
# scroll_depth_pct             float64     54139  96429        96
# time_on_page_sec             float64     54139  96429       537
# bounced                      float64     54139  96429         2

# %% [markdown]
# ### Blank vs zero
#
# `scroll_depth_pct`, `time_on_page_sec` and `bounced` are **blank** — not zero — when `clicked = 0`.
# They are undefined for a session that never reached an article. Written as zeros, a careless
# `df.scroll_depth_pct.mean()` would silently average in ~66% of sessions that never scrolled anything.

# %%
print("nulls in engagement columns, by clicked:")
display(df.groupby("clicked")[["scroll_depth_pct","time_on_page_sec","bounced"]].apply(
    lambda g: g.isna().sum()))
print("\nWRONG (includes non-clicks as if they were 0): ",
      round(df.scroll_depth_pct.fillna(0).mean(), 2))
print("RIGHT (only sessions that clicked):            ",
      round(df.scroll_depth_pct.mean(), 2))
# Out:
# nulls in engagement columns, by clicked:
#          scroll_depth_pct  time_on_page_sec  bounced
# clicked
# 0                   96429             96429    96429
# 1                       0                 0        0
# WRONG (includes non-clicks as if they were 0):  19.08
# RIGHT (only sessions that clicked):             53.07

# %% [markdown]
# ## 8. Integrity checks
#
# Eight structural invariants. Any failure means the generator is broken.

# %%
checks = {
    "variant is constant within user":
        df.groupby("user_id").variant.nunique().eq(1).all(),
    "deks_available <= inscope_impressions":
        (df.deks_available <= df.inscope_impressions).all(),
    "deks_rendered == 0 everywhere in arm A":
        (df.loc[df.variant == "A", "deks_rendered"] == 0).all(),
    "deks_rendered == deks_available in arm B":
        (df.loc[df.variant == "B", "deks_rendered"]
         == df.loc[df.variant == "B", "deks_available"]).all(),
    "full_dek_coverage flag is consistent":
        (df.full_dek_coverage == (df.deks_available == df.inscope_impressions).astype(int)).all(),
    "engagement present iff clicked":
        (df.scroll_depth_pct.notna() == (df.clicked == 1)).all(),
    "articles_clicked == 0 iff not clicked":
        (df.articles_clicked.eq(0) == df.clicked.eq(0)).all(),
    "session_id unique":
        df.session_id.is_unique,
}
for name, ok in checks.items():
    print(f"  {'PASS' if ok else 'FAIL'}  {name}")
assert all(checks.values()), "integrity check failed"
# Out:
#   PASS  variant is constant within user
#   PASS  deks_available <= inscope_impressions
#   PASS  deks_rendered == 0 everywhere in arm A
#   PASS  deks_rendered == deks_available in arm B
#   PASS  full_dek_coverage flag is consistent
#   PASS  engagement present iff clicked
#   PASS  articles_clicked == 0 iff not clicked
#   PASS  session_id unique

# %% [markdown]
# ## 9. Allocation and SRM
#
# SRM (sample ratio mismatch) tests the observed split against the **intended** one — 52/48 here, not 50/50. A deliberately uneven allocation is not an SRM failure; an allocation that drifts from its own configuration is.

# %%
import math

users_by_arm = df.groupby("variant").user_id.nunique()
sess_by_arm  = df.variant.value_counts()

alloc = pd.DataFrame({
    "users":      users_by_arm,
    "user_share": users_by_arm / users_by_arm.sum(),
    "sessions":   sess_by_arm,
    "sess_share": sess_by_arm / sess_by_arm.sum(),
    "sessions_per_user": sess_by_arm / users_by_arm,
})
display(alloc)

n_tot, n_b = users_by_arm.sum(), users_by_arm["B"]
z = (n_b - n_tot * P_ASSIGN_B) / math.sqrt(n_tot * P_ASSIGN_B * (1 - P_ASSIGN_B))
p = math.erfc(abs(z) / math.sqrt(2))
print(f"SRM vs intended {1-P_ASSIGN_B:.0%}/{P_ASSIGN_B:.0%}:  z = {z:+.2f}   p = {p:.3f}   "
      f"-> {'PASS' if p > 0.01 else 'FAIL'}")
# Out:
#          users  user_share  sessions  sess_share  sessions_per_user
# variant
# A        52116     0.52116     78341    0.520303           1.503204
# B        47884     0.47884     72227    0.479697           1.508374
# SRM vs intended 52%/48%:  z = -0.73   p = 0.463   -> PASS

# %% [markdown]
# ## 10. The primary KPI
#
# Session-denominated CTR, by arm. This is just the mean of `clicked`.

# %%
def rate_table(frame, by="variant"):
    g = frame.groupby(by).clicked.agg(sessions="size", conversions="sum")
    g["ctr"] = g.conversions / g.sessions
    return g

primary = rate_table(df)
display(primary.style.format({"sessions":"{:,}", "conversions":"{:,}", "ctr":"{:.4%}"}))

pa, pb = primary.loc["A","ctr"], primary.loc["B","ctr"]
print(f"absolute  {pb-pa:+.4f}  ({(pb-pa)*100:+.2f}pp)")
print(f"relative  {pb/pa-1:+.2%}      (ship threshold +5%)")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac5f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac5f4_level0_col0" class="col_heading level0 col0" >sessions</th>
#       <th id="T_ac5f4_level0_col1" class="col_heading level0 col1" >conversions</th>
#       <th id="T_ac5f4_level0_col2" class="col_heading level0 col2" >ctr</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac5f4_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_ac5f4_row0_col0" class="data row0 col0" >78,341</td>
#       <td id="T_ac5f4_row0_col1" class="data row0 col1" >26,647</td>
#       <td id="T_ac5f4_row0_col2" class="data row0 col2" >34.0141%</td>
#     </tr>
#     <tr>
#       <th id="T_ac5f4_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_ac5f4_row1_col0" class="data row1 col0" >72,227</td>
#       <td id="T_ac5f4_row1_col1" class="data row1 col1" >27,492</td>
#       <td id="T_ac5f4_row1_col2" class="data row1 col2" >38.0633%</td>
#     </tr>
#   </tbody>
# </table>
# absolute  +0.0405  (+4.05pp)
# relative  +11.90%      (ship threshold +5%)

# %% [markdown]
# ## 11. Clustering — why the unit of analysis matters
#
# Two ways to compute the standard error on the same difference:
#
# - **Naive** — treat all 150k sessions as independent
# - **User-clustered** — the delta-method variance for a ratio metric, where each *user* is one
#   observation contributing `n_i` sessions and `k_i` clicks
#
# The ratio of their squares is the **design effect**. Step 1 assumed 1.24 before any data existed.

# %%
def clustered_se(frame):
    g = frame.groupby("user_id").clicked.agg(n="size", k="sum")
    M, nbar = len(g), g.n.mean()
    p = g.k.sum() / g.n.sum()
    v = ((g.k - p * g.n) ** 2).sum() / (M - 1)
    return math.sqrt(v / (M * nbar ** 2)), M, nbar, p

rows_out = []
for arm in ["A", "B"]:
    sub = df[df.variant == arm]
    se_cl, M, nbar, p = clustered_se(sub)
    se_nv = math.sqrt(p * (1 - p) / len(sub))
    rows_out.append({"arm": arm, "users": M, "sessions_per_user": round(nbar, 3),
                     "ctr": p, "se_naive": se_nv, "se_clustered": se_cl,
                     "design_effect": (se_cl / se_nv) ** 2})
se_df = pd.DataFrame(rows_out).set_index("arm")
display(se_df.style.format({"users":"{:,}", "ctr":"{:.4%}",
                            "se_naive":"{:.6f}", "se_clustered":"{:.6f}",
                            "design_effect":"{:.3f}"}))

d      = pb - pa
se_nv  = math.sqrt(pa*(1-pa)/len(df[df.variant=="A"]) + pb*(1-pb)/len(df[df.variant=="B"]))
se_cl  = math.sqrt(se_df.loc["A","se_clustered"]**2 + se_df.loc["B","se_clustered"]**2)
p2     = lambda z: math.erfc(abs(z)/math.sqrt(2))

print(f"naive      SE {se_nv:.6f}   z = {d/se_nv:6.2f}   p = {p2(d/se_nv):.2e}")
print(f"clustered  SE {se_cl:.6f}   z = {d/se_cl:6.2f}   p = {p2(d/se_cl):.2e}")
print(f"\nSE inflation {se_cl/se_nv:.3f}x   ->   design effect {(se_cl/se_nv)**2:.3f}   "
      f"(Step 1 assumed 1.24)")
print(f"\n95% CI on relative lift (clustered): "
      f"[{(d-1.96*se_cl)/pa:+.2%}, {(d+1.96*se_cl)/pa:+.2%}]")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6984d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6984d_level0_col0" class="col_heading level0 col0" >users</th>
#       <th id="T_6984d_level0_col1" class="col_heading level0 col1" >sessions_per_user</th>
#       <th id="T_6984d_level0_col2" class="col_heading level0 col2" >ctr</th>
#       <th id="T_6984d_level0_col3" class="col_heading level0 col3" >se_naive</th>
#       <th id="T_6984d_level0_col4" class="col_heading level0 col4" >se_clustered</th>
#       <th id="T_6984d_level0_col5" class="col_heading level0 col5" >design_effect</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >arm</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6984d_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_6984d_row0_col0" class="data row0 col0" >52,116</td>
#       <td id="T_6984d_row0_col1" class="data row0 col1" >1.503000</td>
#       <td id="T_6984d_row0_col2" class="data row0 col2" >34.0141%</td>
#       <td id="T_6984d_row0_col3" class="data row0 col3" >0.001693</td>
#       <td id="T_6984d_row0_col4" class="data row0 col4" >0.001872</td>
#       <td id="T_6984d_row0_col5" class="data row0 col5" >1.224</td>
#     </tr>
#     <tr>
#       <th id="T_6984d_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_6984d_row1_col0" class="data row1 col0" >47,884</td>
#       <td id="T_6984d_row1_col1" class="data row1 col1" >1.508000</td>
#       <td id="T_6984d_row1_col2" class="data row1 col2" >38.0633%</td>
#       <td id="T_6984d_row1_col3" class="data row1 col3" >0.001807</td>
#       <td id="T_6984d_row1_col4" class="data row1 col4" >0.002009</td>
#       <td id="T_6984d_row1_col5" class="data row1 col5" >1.237</td>
#     </tr>
#   </tbody>
# </table>
# naive      SE 0.002476   z =  16.36   p = 3.95e-60
# clustered  SE 0.002747   z =  14.74   p = 3.44e-49
#
# SE inflation 1.109x   ->   design effect 1.231   (Step 1 assumed 1.24)
#
# 95% CI on relative lift (clustered): [+10.32%, +13.49%]

# %% [markdown]
# ## 12. Dek coverage and ITT dilution
#
# Coverage is a direct multiplier on the measured effect. The **ITT** estimate uses every session as
# assigned; the **availability-conditioned** estimate keeps only sessions where all in-scope slots had
# a dek written — a filter on `dek_available`, which is treatment-independent and therefore applied
# symmetrically to both arms.
#
# Watch the ratio of the two lifts land near the coverage rate. That is dilution behaving exactly as
# an unbiased-but-diluted estimator should.

# %%
coverage = df.deks_available.sum() / df.inscope_impressions.sum()
print(f"in-scope impressions with a dek available: {coverage:.3%}   (launch gate >= 85%)")
print(f"sessions with FULL in-scope coverage:      {df.full_dek_coverage.mean():.2%}")

itt  = rate_table(df)
cond = rate_table(df[df.full_dek_coverage == 1])
lift = lambda t: t.loc["B","ctr"] / t.loc["A","ctr"] - 1

comp = pd.DataFrame({
    "A_ctr":    [itt.loc["A","ctr"],  cond.loc["A","ctr"]],
    "B_ctr":    [itt.loc["B","ctr"],  cond.loc["B","ctr"]],
    "rel_lift": [lift(itt),           lift(cond)],
    "sessions": [itt.sessions.sum(),  cond.sessions.sum()],
}, index=["ITT (all sessions)", "availability-conditioned"])
display(comp.style.format({"A_ctr":"{:.4%}","B_ctr":"{:.4%}",
                           "rel_lift":"{:+.2%}","sessions":"{:,}"}))

print(f"\nITT / conditioned = {lift(itt)/lift(cond):.3f}    coverage = {coverage:.3f}")
# Out:
# in-scope impressions with a dek available: 87.422%   (launch gate >= 85%)
# sessions with FULL in-scope coverage:      53.82%
# <style type="text/css">
# </style>
# <table id="T_a28c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a28c7_level0_col0" class="col_heading level0 col0" >A_ctr</th>
#       <th id="T_a28c7_level0_col1" class="col_heading level0 col1" >B_ctr</th>
#       <th id="T_a28c7_level0_col2" class="col_heading level0 col2" >rel_lift</th>
#       <th id="T_a28c7_level0_col3" class="col_heading level0 col3" >sessions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a28c7_level0_row0" class="row_heading level0 row0" >ITT (all sessions)</th>
#       <td id="T_a28c7_row0_col0" class="data row0 col0" >34.0141%</td>
#       <td id="T_a28c7_row0_col1" class="data row0 col1" >38.0633%</td>
#       <td id="T_a28c7_row0_col2" class="data row0 col2" >+11.90%</td>
#       <td id="T_a28c7_row0_col3" class="data row0 col3" >150,568</td>
#     </tr>
#     <tr>
#       <th id="T_a28c7_level0_row1" class="row_heading level0 row1" >availability-conditioned</th>
#       <td id="T_a28c7_row1_col0" class="data row1 col0" >33.9318%</td>
#       <td id="T_a28c7_row1_col1" class="data row1 col1" >38.5422%</td>
#       <td id="T_a28c7_row1_col2" class="data row1 col2" >+13.59%</td>
#       <td id="T_a28c7_row1_col3" class="data row1 col3" >81,040</td>
#     </tr>
#   </tbody>
# </table>
# ITT / conditioned = 0.876    coverage = 0.874

# %% [markdown]
# ## 13. Time: weekly cycle, the news shock, and novelty

# %%
daily = (df.assign(d=df.session_date.dt.date)
           .groupby(["d","variant"]).clicked.agg(sessions="size", clicks="sum")
           .reset_index())
daily["ctr"] = daily.clicks / daily.sessions
daily_p = daily.pivot(index="d", columns="variant", values=["sessions","ctr"])
daily_p[("ctr","rel_lift")] = daily_p[("ctr","B")] / daily_p[("ctr","A")] - 1
display(daily_p.head(10))
# Out:
#            sessions               ctr
# variant           A       B         A         B  rel_lift
# d
# 2026-09-22   2682.0  2469.0  0.329605  0.375051  0.137880
# 2026-09-23   1922.0  1763.0  0.344433  0.366421  0.063838
# 2026-09-24   2382.0  2254.0  0.343829  0.382875  0.113563
# 2026-09-25   2046.0  1937.0  0.341642  0.370676  0.084984
# 2026-09-26   2191.0  1929.0  0.352351  0.403318  0.144649
# 2026-09-27   1651.0  1433.0  0.355542  0.381019  0.071656
# 2026-09-28   2594.0  2315.0  0.327679  0.371922  0.135019
# 2026-09-29   2124.0  1915.0  0.353107  0.362402  0.026323
# 2026-09-30   2539.0  2356.0  0.328082  0.386248  0.177291
# 2026-10-01   2643.0  2433.0  0.345819  0.373202  0.079182

# %%
week = (df.assign(week=((df.session_date - pd.Timestamp(START)).dt.days // 7) + 1)
          .groupby(["week","variant"]).clicked.agg(sessions="size", clicks="sum"))
week["ctr"] = week.clicks / week.sessions
wk = week.ctr.unstack("variant")
wk["rel_lift"] = wk.B / wk.A - 1
wk["sessions"] = week.sessions.unstack("variant").sum(axis=1)
display(wk.style.format({"A":"{:.4%}","B":"{:.4%}","rel_lift":"{:+.2%}","sessions":"{:,}"}))

print("The novelty term is in the generating process (1 + 0.25*exp(-day/9)) but is NOT")
print("statistically visible here: a 0.25 swing in the log-odds multiplier is smaller than")
print("weekly sampling noise at ~14k sessions per arm per week. Week-sliced novelty checks")
print("are badly underpowered. Raise NOVELTY_PEAK if you want a detectable decay.")
# Out:
# <style type="text/css">
# </style>
# <table id="T_de923">
#   <thead>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th id="T_de923_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_de923_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_de923_level0_col2" class="col_heading level0 col2" >rel_lift</th>
#       <th id="T_de923_level0_col3" class="col_heading level0 col3" >sessions</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >week</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de923_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_de923_row0_col0" class="data row0 col0" >34.0897%</td>
#       <td id="T_de923_row0_col1" class="data row0 col1" >37.8582%</td>
#       <td id="T_de923_row0_col2" class="data row0 col2" >+11.05%</td>
#       <td id="T_de923_row0_col3" class="data row0 col3" >29,568</td>
#     </tr>
#     <tr>
#       <th id="T_de923_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_de923_row1_col0" class="data row1 col0" >34.0773%</td>
#       <td id="T_de923_row1_col1" class="data row1 col1" >38.0072%</td>
#       <td id="T_de923_row1_col2" class="data row1 col2" >+11.53%</td>
#       <td id="T_de923_row1_col3" class="data row1 col3" >31,738</td>
#     </tr>
#     <tr>
#       <th id="T_de923_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_de923_row2_col0" class="data row2 col0" >34.2393%</td>
#       <td id="T_de923_row2_col1" class="data row2 col1" >38.5151%</td>
#       <td id="T_de923_row2_col2" class="data row2 col2" >+12.49%</td>
#       <td id="T_de923_row2_col3" class="data row2 col3" >31,998</td>
#     </tr>
#     <tr>
#       <th id="T_de923_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_de923_row3_col0" class="data row3 col0" >33.7451%</td>
#       <td id="T_de923_row3_col1" class="data row3 col1" >38.2439%</td>
#       <td id="T_de923_row3_col2" class="data row3 col2" >+13.33%</td>
#       <td id="T_de923_row3_col3" class="data row3 col3" >28,606</td>
#     </tr>
#     <tr>
#       <th id="T_de923_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_de923_row4_col0" class="data row4 col0" >33.8823%</td>
#       <td id="T_de923_row4_col1" class="data row4 col1" >37.6535%</td>
#       <td id="T_de923_row4_col2" class="data row4 col2" >+11.13%</td>
#       <td id="T_de923_row4_col3" class="data row4 col3" >28,658</td>
#     </tr>
#   </tbody>
# </table>
# The novelty term is in the generating process (1 + 0.25*exp(-day/9)) but is NOT
# statistically visible here: a 0.25 swing in the log-odds multiplier is smaller than
# weekly sampling noise at ~14k sessions per arm per week. Week-sliced novelty checks
# are badly underpowered. Raise NOVELTY_PEAK if you want a detectable decay.

# %% [markdown]
# ## 14. Segments
#
# Exploratory only, per the pre-registration — a segment result can justify a follow-up test, never a rollout. Sort by `rel_lift` and note how the widest intervals sit at the extremes.

# %%
def segment_table(frame, specs):
    out = []
    for label, series in specs.items():
        g = frame.assign(_k=series).groupby(["_k","variant"]).clicked.agg(n="size", k="sum")
        for key in g.index.get_level_values(0).unique():
            try:
                a, b = g.loc[(key,"A")], g.loc[(key,"B")]
            except KeyError:
                continue
            if a.n < 500 or b.n < 500:
                continue
            pa_, pb_ = a.k/a.n, b.k/b.n
            se = math.sqrt(pa_*(1-pa_)/a.n + pb_*(1-pb_)/b.n)
            out.append({"segment": f"{label}={key}", "sessions": int(a.n+b.n),
                        "A_ctr": pa_, "B_ctr": pb_, "rel_lift": pb_/pa_-1,
                        "ci_lo": (pb_-pa_-1.96*se)/pa_, "ci_hi": (pb_-pa_+1.96*se)/pa_,
                        "z": (pb_-pa_)/se})
    return pd.DataFrame(out).set_index("segment").sort_values("rel_lift")

seg = segment_table(df, {
    "device":     df.device,
    "logged_in":  df.is_logged_in.map({0:"no", 1:"yes"}),
    "subscriber": df.is_subscriber.map({0:"no", 1:"yes"}),
    "visitor":    df.visitor_type,
    "dow":        df.day_of_week,
})
display(seg.style.format({"sessions":"{:,}","A_ctr":"{:.2%}","B_ctr":"{:.2%}",
                          "rel_lift":"{:+.2%}","ci_lo":"{:+.2%}","ci_hi":"{:+.2%}","z":"{:.2f}"}))
print(f"\nsegments with negative point estimate: {(seg.rel_lift < 0).sum()} of {len(seg)}")
print(f"segments whose CI contains the +5% ship bar: "
      f"{((seg.ci_lo < 0.05) & (seg.ci_hi > 0.05)).sum()} of {len(seg)}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f8cfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8cfb_level0_col0" class="col_heading level0 col0" >sessions</th>
#       <th id="T_f8cfb_level0_col1" class="col_heading level0 col1" >A_ctr</th>
#       <th id="T_f8cfb_level0_col2" class="col_heading level0 col2" >B_ctr</th>
#       <th id="T_f8cfb_level0_col3" class="col_heading level0 col3" >rel_lift</th>
#       <th id="T_f8cfb_level0_col4" class="col_heading level0 col4" >ci_lo</th>
#       <th id="T_f8cfb_level0_col5" class="col_heading level0 col5" >ci_hi</th>
#       <th id="T_f8cfb_level0_col6" class="col_heading level0 col6" >z</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8cfb_level0_row0" class="row_heading level0 row0" >subscriber=yes</th>
#       <td id="T_f8cfb_row0_col0" class="data row0 col0" >9,103</td>
#       <td id="T_f8cfb_row0_col1" class="data row0 col1" >47.15%</td>
#       <td id="T_f8cfb_row0_col2" class="data row0 col2" >48.54%</td>
#       <td id="T_f8cfb_row0_col3" class="data row0 col3" >+2.95%</td>
#       <td id="T_f8cfb_row0_col4" class="data row0 col4" >-1.41%</td>
#       <td id="T_f8cfb_row0_col5" class="data row0 col5" >+7.31%</td>
#       <td id="T_f8cfb_row0_col6" class="data row0 col6" >1.33</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row1" class="row_heading level0 row1" >dow=Sun</th>
#       <td id="T_f8cfb_row1_col0" class="data row1 col0" >18,668</td>
#       <td id="T_f8cfb_row1_col1" class="data row1 col1" >34.66%</td>
#       <td id="T_f8cfb_row1_col2" class="data row1 col2" >37.92%</td>
#       <td id="T_f8cfb_row1_col3" class="data row1 col3" >+9.39%</td>
#       <td id="T_f8cfb_row1_col4" class="data row1 col4" >+5.40%</td>
#       <td id="T_f8cfb_row1_col5" class="data row1 col5" >+13.37%</td>
#       <td id="T_f8cfb_row1_col6" class="data row1 col6" >4.62</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row2" class="row_heading level0 row2" >logged_in=yes</th>
#       <td id="T_f8cfb_row2_col0" class="data row2 col0" >46,723</td>
#       <td id="T_f8cfb_row2_col1" class="data row2 col1" >41.12%</td>
#       <td id="T_f8cfb_row2_col2" class="data row2 col2" >45.22%</td>
#       <td id="T_f8cfb_row2_col3" class="data row2 col3" >+9.97%</td>
#       <td id="T_f8cfb_row2_col4" class="data row2 col4" >+7.78%</td>
#       <td id="T_f8cfb_row2_col5" class="data row2 col5" >+12.15%</td>
#       <td id="T_f8cfb_row2_col6" class="data row2 col6" >8.94</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row3" class="row_heading level0 row3" >dow=Mon</th>
#       <td id="T_f8cfb_row3_col0" class="data row3 col0" >22,521</td>
#       <td id="T_f8cfb_row3_col1" class="data row3 col1" >33.67%</td>
#       <td id="T_f8cfb_row3_col2" class="data row3 col2" >37.34%</td>
#       <td id="T_f8cfb_row3_col3" class="data row3 col3" >+10.90%</td>
#       <td id="T_f8cfb_row3_col4" class="data row3 col4" >+7.19%</td>
#       <td id="T_f8cfb_row3_col5" class="data row3 col5" >+14.62%</td>
#       <td id="T_f8cfb_row3_col6" class="data row3 col6" >5.75</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row4" class="row_heading level0 row4" >visitor=returning</th>
#       <td id="T_f8cfb_row4_col0" class="data row4 col0" >97,695</td>
#       <td id="T_f8cfb_row4_col1" class="data row4 col1" >37.96%</td>
#       <td id="T_f8cfb_row4_col2" class="data row4 col2" >42.20%</td>
#       <td id="T_f8cfb_row4_col3" class="data row4 col3" >+11.18%</td>
#       <td id="T_f8cfb_row4_col4" class="data row4 col4" >+9.56%</td>
#       <td id="T_f8cfb_row4_col5" class="data row4 col5" >+12.80%</td>
#       <td id="T_f8cfb_row4_col6" class="data row4 col6" >13.52</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row5" class="row_heading level0 row5" >device=mobile</th>
#       <td id="T_f8cfb_row5_col0" class="data row5 col0" >93,314</td>
#       <td id="T_f8cfb_row5_col1" class="data row5 col1" >31.80%</td>
#       <td id="T_f8cfb_row5_col2" class="data row5 col2" >35.41%</td>
#       <td id="T_f8cfb_row5_col3" class="data row5 col3" >+11.37%</td>
#       <td id="T_f8cfb_row5_col4" class="data row5 col4" >+9.46%</td>
#       <td id="T_f8cfb_row5_col5" class="data row5 col5" >+13.27%</td>
#       <td id="T_f8cfb_row5_col6" class="data row5 col6" >11.68</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row6" class="row_heading level0 row6" >dow=Tue</th>
#       <td id="T_f8cfb_row6_col0" class="data row6 col0" >22,699</td>
#       <td id="T_f8cfb_row6_col1" class="data row6 col1" >33.81%</td>
#       <td id="T_f8cfb_row6_col2" class="data row6 col2" >37.80%</td>
#       <td id="T_f8cfb_row6_col3" class="data row6 col3" >+11.79%</td>
#       <td id="T_f8cfb_row6_col4" class="data row6 col4" >+8.10%</td>
#       <td id="T_f8cfb_row6_col5" class="data row6 col5" >+15.48%</td>
#       <td id="T_f8cfb_row6_col6" class="data row6 col6" >6.26</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row7" class="row_heading level0 row7" >dow=Thu</th>
#       <td id="T_f8cfb_row7_col0" class="data row7 col0" >22,059</td>
#       <td id="T_f8cfb_row7_col1" class="data row7 col1" >33.99%</td>
#       <td id="T_f8cfb_row7_col2" class="data row7 col2" >38.10%</td>
#       <td id="T_f8cfb_row7_col3" class="data row7 col3" >+12.11%</td>
#       <td id="T_f8cfb_row7_col4" class="data row7 col4" >+8.38%</td>
#       <td id="T_f8cfb_row7_col5" class="data row7 col5" >+15.84%</td>
#       <td id="T_f8cfb_row7_col6" class="data row7 col6" >6.36</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row8" class="row_heading level0 row8" >dow=Sat</th>
#       <td id="T_f8cfb_row8_col0" class="data row8 col0" >20,986</td>
#       <td id="T_f8cfb_row8_col1" class="data row8 col1" >35.38%</td>
#       <td id="T_f8cfb_row8_col2" class="data row8 col2" >39.69%</td>
#       <td id="T_f8cfb_row8_col3" class="data row8 col3" >+12.16%</td>
#       <td id="T_f8cfb_row8_col4" class="data row8 col4" >+8.46%</td>
#       <td id="T_f8cfb_row8_col5" class="data row8 col5" >+15.87%</td>
#       <td id="T_f8cfb_row8_col6" class="data row8 col6" >6.43</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row9" class="row_heading level0 row9" >device=desktop</th>
#       <td id="T_f8cfb_row9_col0" class="data row9 col0" >44,430</td>
#       <td id="T_f8cfb_row9_col1" class="data row9 col1" >38.67%</td>
#       <td id="T_f8cfb_row9_col2" class="data row9 col2" >43.53%</td>
#       <td id="T_f8cfb_row9_col3" class="data row9 col3" >+12.58%</td>
#       <td id="T_f8cfb_row9_col4" class="data row9 col4" >+10.21%</td>
#       <td id="T_f8cfb_row9_col5" class="data row9 col5" >+14.94%</td>
#       <td id="T_f8cfb_row9_col6" class="data row9 col6" >10.42</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row10" class="row_heading level0 row10" >subscriber=no</th>
#       <td id="T_f8cfb_row10_col0" class="data row10 col0" >141,465</td>
#       <td id="T_f8cfb_row10_col1" class="data row10 col1" >33.17%</td>
#       <td id="T_f8cfb_row10_col2" class="data row10 col2" >37.39%</td>
#       <td id="T_f8cfb_row10_col3" class="data row10 col3" >+12.73%</td>
#       <td id="T_f8cfb_row10_col4" class="data row10 col4" >+11.23%</td>
#       <td id="T_f8cfb_row10_col5" class="data row10 col5" >+14.23%</td>
#       <td id="T_f8cfb_row10_col6" class="data row10 col6" >16.61</td>
#     </tr>
#     <tr>
#       <th id="T_f8cfb_level0_row11" class="row_heading level0 row11" >logged_in=no</th>
#       <td id="T_f8cfb_row11_col0" class="data row11 col0" >103,845</td>
#       <td id="T_f8cfb_row11_col1" class="data row11 col1" >30.81%</td>
#       <td id="T_f8cfb_row11_col2" class="data row11 col2" >34.85%</td>
#       <td id="T_f8cfb_row11_col3" class="data row11 col3" >+13.10%</td>
#       <td id="T_f8cfb_row11_col4" class="data row11 col4" >+11.24%</td>
# segments with negative point estimate: 0 of 16
# segments whose CI contains the +5% ship bar: 1 of 16

# %% [markdown]
# ## 15. Secondary metrics
#
# Higher CTR *with* deeper engagement is the relevance mechanism from the hypothesis. The satisfaction risk would have looked like the opposite: more clicks, worse engagement.

# %%
clicked = df[df.clicked == 1]
sec = pd.DataFrame({
    "homepage_impressions_per_session": df.groupby("variant").homepage_impressions.mean(),
    "inscope_impressions_per_session":  df.groupby("variant").inscope_impressions.mean(),
    "articles_per_reading_session":     clicked.groupby("variant").articles_clicked.mean(),
    "scroll_depth_pct":                 clicked.groupby("variant").scroll_depth_pct.mean(),
    "time_on_page_sec":                 clicked.groupby("variant").time_on_page_sec.mean(),
    "bounce_rate":                      clicked.groupby("variant").bounced.mean(),
}).T
sec["change"] = sec.B / sec.A - 1
display(sec.style.format({"A":"{:.3f}","B":"{:.3f}","change":"{:+.2%}"}))

print("\nhomepage impressions per session is the vertical-space cost: deks push stories down.")
print("Ad impressions per session was excluded in Step 1 as not instrumented, so the inventory")
print("consequence of that drop is unmeasured here by design.")
# Out:
# <style type="text/css">
# </style>
# <table id="T_18f2a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >variant</th>
#       <th id="T_18f2a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_18f2a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_18f2a_level0_col2" class="col_heading level0 col2" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18f2a_level0_row0" class="row_heading level0 row0" >homepage_impressions_per_session</th>
#       <td id="T_18f2a_row0_col0" class="data row0 col0" >11.270</td>
#       <td id="T_18f2a_row0_col1" class="data row0 col1" >10.784</td>
#       <td id="T_18f2a_row0_col2" class="data row0 col2" >-4.31%</td>
#     </tr>
#     <tr>
#       <th id="T_18f2a_level0_row1" class="row_heading level0 row1" >inscope_impressions_per_session</th>
#       <td id="T_18f2a_row1_col0" class="data row1 col0" >4.795</td>
#       <td id="T_18f2a_row1_col1" class="data row1 col1" >4.786</td>
#       <td id="T_18f2a_row1_col2" class="data row1 col2" >-0.19%</td>
#     </tr>
#     <tr>
#       <th id="T_18f2a_level0_row2" class="row_heading level0 row2" >articles_per_reading_session</th>
#       <td id="T_18f2a_row2_col0" class="data row2 col0" >1.423</td>
#       <td id="T_18f2a_row2_col1" class="data row2 col1" >1.418</td>
#       <td id="T_18f2a_row2_col2" class="data row2 col2" >-0.35%</td>
#     </tr>
#     <tr>
#       <th id="T_18f2a_level0_row3" class="row_heading level0 row3" >scroll_depth_pct</th>
#       <td id="T_18f2a_row3_col0" class="data row3 col0" >51.870</td>
#       <td id="T_18f2a_row3_col1" class="data row3 col1" >54.224</td>
#       <td id="T_18f2a_row3_col2" class="data row3 col2" >+4.54%</td>
#     </tr>
#     <tr>
#       <th id="T_18f2a_level0_row4" class="row_heading level0 row4" >time_on_page_sec</th>
#       <td id="T_18f2a_row4_col0" class="data row4 col0" >94.785</td>
#       <td id="T_18f2a_row4_col1" class="data row4 col1" >100.238</td>
#       <td id="T_18f2a_row4_col2" class="data row4 col2" >+5.75%</td>
#     </tr>
#     <tr>
#       <th id="T_18f2a_level0_row5" class="row_heading level0 row5" >bounce_rate</th>
#       <td id="T_18f2a_row5_col0" class="data row5 col0" >0.378</td>
#       <td id="T_18f2a_row5_col1" class="data row5 col1" >0.353</td>
#       <td id="T_18f2a_row5_col2" class="data row5 col2" >-6.66%</td>
#     </tr>
#   </tbody>
# </table>
# homepage impressions per session is the vertical-space cost: deks push stories down.
# Ad impressions per session was excluded in Step 1 as not instrumented, so the inventory
# consequence of that drop is unmeasured here by design.

# %% [markdown]
# ## 16. Charts

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.rcParams.update({"figure.dpi": 110, "axes.grid": True, "grid.alpha": 0.25,
                     "axes.spines.top": False, "axes.spines.right": False,
                     "font.size": 9})
CA, CB = "#6b7280", "#2563eb"          # A grey, B blue
shock_date = pd.Timestamp(START) + pd.Timedelta(days=NEWS_SPIKE_DAY)

fig, ax = plt.subplots(2, 1, figsize=(10, 6), sharex=True,
                       gridspec_kw={"height_ratios": [2, 1]})
piv_ctr = daily.pivot(index="d", columns="variant", values="ctr")
piv_ses = daily.pivot(index="d", columns="variant", values="sessions")

ax[0].plot(piv_ctr.index, piv_ctr.A, color=CA, marker="o", ms=3, lw=1.2, label="A — headline only")
ax[0].plot(piv_ctr.index, piv_ctr.B, color=CB, marker="o", ms=3, lw=1.2, label="B — headline + dek")
ax[0].axhline(pa, color=CA, ls=":", lw=1)
ax[0].axhline(pb, color=CB, ls=":", lw=1)
ax[0].axvline(shock_date, color="#dc2626", ls="--", lw=1)
ax[0].annotate("news shock\n(coverage 71%)", (shock_date, ax[0].get_ylim()[1]),
               xytext=(6, -26), textcoords="offset points", fontsize=8, color="#dc2626")
ax[0].set_ylabel("session CTR")
ax[0].set_title("Daily session-denominated CTR by arm", loc="left", fontsize=11)
ax[0].legend(frameon=False, loc="lower right")

ax[1].bar(piv_ses.index, piv_ses.A, color=CA, width=0.8, label="A")
ax[1].bar(piv_ses.index, piv_ses.B, bottom=piv_ses.A, color=CB, width=0.8, label="B")
ax[1].axvline(shock_date, color="#dc2626", ls="--", lw=1)
ax[1].set_ylabel("sessions")
ax[1].set_title("Daily traffic — weekly cycle plus one shock", loc="left", fontsize=11)
ax[1].xaxis.set_major_formatter(mdates.DateFormatter("%b %d"))
fig.autofmt_xdate()
plt.tight_layout(); plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3.4))

ax[0].plot(pd.to_datetime(days_df.date), days_df.coverage, color="#059669", marker="o", ms=3, lw=1.2)
ax[0].axhline(0.85, color="#dc2626", ls="--", lw=1)
ax[0].annotate("85% launch gate", (pd.to_datetime(days_df.date.iloc[1]), 0.852),
               fontsize=8, color="#dc2626")
ax[0].set_ylim(0.6, 1.0); ax[0].set_ylabel("dek coverage")
ax[0].set_title("Dek coverage by day", loc="left", fontsize=11)
ax[0].xaxis.set_major_formatter(mdates.DateFormatter("%b %d"))
ax[0].tick_params(axis="x", rotation=45)

spu = df.groupby("user_id").size().value_counts().sort_index()
ax[1].bar(spu.index, spu.values, color="#7c3aed", width=0.75)
ax[1].set_yscale("log")
ax[1].set_xlabel("sessions per user"); ax[1].set_ylabel("users (log)")
ax[1].set_title(f"Sessions per user — overdispersed, mean {df.groupby('user_id').size().mean():.2f}",
                loc="left", fontsize=11)
plt.tight_layout(); plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4.6))
s = seg.sort_values("rel_lift")
y = range(len(s))
ax.errorbar(s.rel_lift, y,
            xerr=[s.rel_lift - s.ci_lo, s.ci_hi - s.rel_lift],
            fmt="o", ms=4, color=CB, ecolor="#93c5fd", elinewidth=2, capsize=0)
ax.axvline(0, color="#111827", lw=1)
ax.axvline(0.05, color="#dc2626", ls="--", lw=1.2)
ax.axvline(pb/pa - 1, color="#059669", ls=":", lw=1.2)
ax.annotate("+5% ship bar", (0.05, len(s)-0.4), xytext=(4, 0), textcoords="offset points",
            fontsize=8, color="#dc2626")
ax.annotate("overall", (pb/pa - 1, -0.6), xytext=(4, 0), textcoords="offset points",
            fontsize=8, color="#059669")
ax.set_yticks(list(y)); ax.set_yticklabels(s.index, fontsize=8)
ax.xaxis.set_major_formatter(lambda v, _: f"{v:+.0%}")
ax.set_xlabel("relative lift (95% CI)")
ax.set_title("Segment lifts — exploratory, and note the widths", loc="left", fontsize=11)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## Caveats
#
# **The effect size is deliberately generous.** The brief asked for a 10–30% uplift, so the dataset
# carries about +12% relative. Step 1 set the ship threshold at +5% and powered for +2%. A real dek
# would not plausibly move session CTR by twelve percent.
#
# The consequence shows up throughout this notebook: the clustering correction, the ITT dilution and
# the underpowered subscriber segment are all clearly **visible**, but none of them changes the
# answer. At a realistic +3% effect each one would be decisive. Set `TARGET_B = 0.351` and re-run to
# get that version — it is a much harder test of whether the Step 1 analysis plan is any good.
#
# **Everything here is synthetic.** The generating process is a logistic model we wrote ourselves, so
# any "finding" is a property of our own assumptions. The notebook is a rehearsal of the analysis, not
# evidence about headlines.
